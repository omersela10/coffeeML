# %%
from PIL import Image

from ultralytics import YOLO

import time
# Mount Google Drive

# Path to your image
images_path = r"C:\Users\USER\git\coffeeML\YOLO_V8\businesses_photos"
print("Start")
# Record the start time
start_time = time.time()

# Load the pre-trained YOLOv8 model
model = YOLO(r"C:\Users\USER\git\coffeeML\YOLO_V8\GoogleColab\runs-20240406T160452Z-001\runs\detect\train3\weights\best.pt")  # Assuming "yolov8n.pt" is your model file

# Perform object detection on the image
results = model.predict(images_path)

# Record the end time
end_time = time.time()

# Calculate the total time taken
total_time = end_time - start_time
print("Total time taken:", total_time, "seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from PIL import Image
# ----> 3 from ultralytics import YOLO
#       5 import time
#       6 # Mount Google Drive
#       7
#       8 # Path to your image
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = "8.1.20"
# ----> 5 from ultralytics.data.explorer.explorer import Explorer
#       6 from ultralytics.models import RTDETR, SAM, YOLO, YOLOWorld
#       7 from ultralytics.models.fastsam import FastSAM
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\data\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ...
