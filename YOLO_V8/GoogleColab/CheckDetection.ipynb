# %%
from PIL import Image

from ultralytics import YOLO
from google.colab import drive
import time
# Mount Google Drive
drive.mount('/content/drive')
# Path to your image
images_path = "/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/Dataset/test/images/food.png"

# Record the start time
start_time = time.time()

# Load the pre-trained YOLOv8 model
model = YOLO("/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/runs/detect/train2/weights/best.pt")  # Assuming "yolov8n.pt" is your model file

# Perform object detection on the image
results = model.predict(images_path)

# Record the end time
end_time = time.time()

# Calculate the total time taken
total_time = end_time - start_time
print("Total time taken:", total_time, "seconds")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# image 1/1 /content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/Dataset/test/images/food.png: 384x640 (no detections), 149.7ms
# Speed: 3.5ms preprocess, 149.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total time taken: 2.1859593391418457 seconds
