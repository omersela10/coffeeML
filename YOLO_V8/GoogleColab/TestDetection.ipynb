# %%
from PIL import Image

from ultralytics import YOLO
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Path to your image
image_path = "/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/Dataset/test/images/1edc1e6648fac0b8.jpg"

# Load the pre-trained YOLOv8 model
model = YOLO("/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/yolov8n_trained.pt")  # Assuming "yolov8n.pt" is your model file


# Perform object detection on the image
results = model.predict(image_path, conf = 0.5, show=True)

# Display the results
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/Dataset/test/images/1edc1e6648fac0b8.jpg: 640x640 1 spoon, 1 cake, 1 dining table, 16.7ms
# Speed: 4.5ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !pip install ultralytics
from ultralytics import YOLO
from google.colab import drive

import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Load the image-label mapping table
#mapping_table_path = f"/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos
final_model_path = "/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/yolov8n_trained.pt"

# Define the data configuration file path
data_config_path = f"/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/config.yaml"
checkpoint_dir = "/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/checkpoints"
# Create a YOLO object for object detection
model = YOLO(f"/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/yolov8n.pt")  # Assuming "yolov8n.pt" is a pre-trained model

# Train the model on your coffee cup dataset
results = model.train(data=data_config_path, epochs=10, save_dir=checkpoint_dir, single_cls=True)

# Adjust the model output for binary classification

# Save the final trained weights
model.save(final_model_path)


# Define the source and destination paths
source_path = '/content/runs'
destination_path = '/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/runs'

# Remove the existing destination directory if it exists
shutil.rmtree(destination_path, ignore_errors=True)

# Copy the directory recursively
shutil.copytree(source_path, destination_path)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━ 399.1/731.7 MB 1.4 MB/s eta 0:04:06

# %%
import shutil
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the source and destination paths
source_path = '/content/runs'
destination_path = '/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/runs'

# Remove the existing destination directory if it exists
shutil.rmtree(destination_path, ignore_errors=True)

# Copy the directory recursively
shutil.copytree(source_path, destination_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/Colab Notebooks/YOLOV8 Photos/runs'
