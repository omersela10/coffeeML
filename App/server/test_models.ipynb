# %% [markdown]
# test object detection:

# %%
#!pip install Pillow
#!pip install ultralytics

from PIL import Image
from ultralytics import YOLO 

# Paths to the image and model
image_paths = [
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(10).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(4)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(28)_augmented_11.jpg",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffee6.png",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffee7.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\food1.png" 
               ]
model_path = r"resources\\MLmodels\\object_detection\\object_detection_v1.pt"


# Initialize model
model = YOLO(model_path) 
for image_path in image_paths:
    try:
        # Perform object detection on the image
        print(f"Performing object detection on image: {image_path}")
        results = model.predict(image_path,show=False)
        if len(results) > 0 and len(results[0].boxes) > 0:
            predicted_class_id = int(results[0].boxes[0].cls)
            print(f"Predicted class ID: {predicted_class_id}")
        else:
            predicted_class_id = -1  # If no prediction is made, assign an invalid class ID
            print("No prediction was made")
        print("")
        # Print results to console

        # Display the results (show=True should handle this if the method supports it)
    except Exception as e:
        print(f"An error occurred: {e}")


# Optionally, print additional information or save results
# print(results.xyxy)  # Print bounding boxes and class predictions
# results.save()  # Save the image with annotations
# Out:
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(8).jpg: 640x640 2 Coffee_cups, 163.4ms
# Speed: 0.0ms preprocess, 163.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Predicted class ID: 0
#
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(10).jpg
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(10).jpg: 640x640 2 Coffee_cups, 138.3ms
# Speed: 0.0ms preprocess, 138.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Predicted class ID: 0
#
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(4)_augmented_1.jpg
#
# ...

# %% [markdown]
# test object type_of_coffee:

# %%
#!pip install Pillow
#!pip install ultralytics

from PIL import Image
from ultralytics import YOLO 

# Paths to the image and model
image_paths = [
                #r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                #r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(10).jpg",
                #r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(4)_augmented_1.jpg",
                #r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(28)_augmented_11.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_2.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_3.jpg",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png"
                #r"C:\\Users\omers\\OneDrive\\Desktop\\coffee6.png",
                #r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png",
               ]

model_path = r"resources\\MLmodels\\coffee_type_classification\\coffee_type_classification_v1.pt"
# Class labels
class_labels = ['Cappuccino', 'Espresso', 'Black Coffee']

# Initialize model
model = YOLO(model_path) 
for image_path in image_paths:
    try:
        print(f"Performing type_of_coffee classification on image: {image_path}")
        
        # Perform prediction
        results = model.predict(image_path, device='cpu', conf=0.5)
         # Extract the predicted class with the highest confidence
        if len(results) > 0 and len(results[0].boxes) > 0:
            predicted_class_id = int(results[0].boxes[0].cls)
            print(class_labels[predicted_class_id])
        else:
            print("Unknown")  # Return Unknown if no prediction is made
        print("")
        # Print results to console

        # Display the results (show=True should handle this if the method supports it)
    except Exception as e:
        print(f"An error occurred: {e}")


# Optionally, print additional information or save results
# print(results.xyxy)  # Print bounding boxes and class predictions
# results.save()  # Save the image with annotations
# Out:
# Performing type_of_coffee classification on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 1 Black, 27.0ms
# Speed: 0.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Black Coffee
#
# Performing type_of_coffee classification on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1)_augmented_1.jpg: 224x224 1 Black, 19.4ms
# Speed: 0.6ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Black Coffee
#
# Performing type_of_coffee classification on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_2.jpg
#
# ...

# %% [markdown]
# test creame:

# %%
#!pip install Pillow
#!pip install ultralytics

from PIL import Image
from ultralytics import YOLO 

# Paths to the image and model
image_paths = [
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_2.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_3.jpg",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png"
               ]

model_path = r"resources\\MLmodels\\crema_classification\\crema_classification_v1.pt"

class_labels = ['No_Crema', 'Crema']

# Initialize model
model = YOLO(model_path) 
for image_path in image_paths:
    try:
        # Perform prediction
        results = model.predict(image_path, device='cpu', conf=0.5)
         # Extract the predicted class with the highest confidence
        if len(results) > 0 and len(results[0].boxes) > 0:
            predicted_class_id = int(results[0].boxes[0].cls)
            print(class_labels[predicted_class_id])
        else:
            print("Unknown")  # Return Unknown if no prediction is made
        print("")

        # Display the results (show=True should handle this if the method supports it)
    except Exception as e:
        print(f"An error occurred: {e}")


# Optionally, print additional information or save results
# print(results.xyxy)  # Print bounding boxes and class predictions
# results.save()  # Save the image with annotations
# Out:
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(8).jpg: 224x224 1 Crema, 26.7ms
# Speed: 0.0ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Crema
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Cremas, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# No_Crema
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1)_augmented_1.jpg: 224x224 2 No_Cremas, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 224)
# No_Crema
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1)_augmented_2.jpg: 224x224 1 No_Crema, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# No_Crema
#
#
# ...

# %% [markdown]
# test served_way:

# %%
#!pip install Pillow
#!pip install ultralytics

from PIL import Image
from ultralytics import YOLO 

# Paths to the image and model
image_paths = [
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_2.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_3.jpg",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png"
               ]

model_path = r"resources\\MLmodels\\served_way_classification\\served_way_classification_v1.pt"

class_labels = ['No_Served_Way', 'Yes_Served_Way']

# Initialize model
model = YOLO(model_path) 
for image_path in image_paths:
    try:
        # Perform prediction
        results = model.predict(image_path, device='cpu', conf=0.4)

        # Extract the predicted class with the highest confidence
        if len(results) > 0 and len(results[0].boxes) > 0:
            predicted_class_id = int(results[0].boxes[0].cls)
            print(class_labels[predicted_class_id])
        else:
            predicted_class_id = -1  # If no prediction is made, assign an invalid class ID
            print("Unknown")
        print("")
        # Print results to console

        # Display the results (show=True should handle this if the method supports it)
    except Exception as e:
        print(f"An error occurred: {e}")


# Optionally, print additional information or save results
# print(results.xyxy)  # Print bounding boxes and class predictions
# results.save()  # Save the image with annotations
# Out:
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(8).jpg: 224x224 1 Yes_Served_Way, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Yes_Served_Way
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Served_Ways, 34.3ms
# Speed: 0.0ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# No_Served_Way
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1)_augmented_1.jpg: 224x224 2 No_Served_Ways, 10.6ms
# Speed: 4.3ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# No_Served_Way
#
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1)_augmented_2.jpg: 224x224 1 No_Served_Way, 21.2ms
# Speed: 0.2ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ...

# %% [markdown]
# test type_of_cup:

# %%
#!pip install Pillow
#!pip install ultralytics

from PIL import Image
from ultralytics import YOLO 

# Paths to the image and model
image_paths = [
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8)_augmented_2.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_2.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_3.jpg",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png"
               ]

model_path = r"resources\\MLmodels\\type_of_cup_classification\\type_of_cup_classification_v1.pt"

class_labels = ['TakeAWay', 'Cup']

# Initialize model
model = YOLO(model_path) 
for image_path in image_paths:
    try:
        # Perform object detection on the image
        print(f"Performing object detection on image: {image_path}")
        results = model.predict(image_path, conf=0.5, show=False)
            # Extract the predicted class with the highest confidence
        if len(results) > 0 and len(results[0].boxes) > 0:
            predicted_class_id = int(results[0].boxes[0].cls)
            print(class_labels[predicted_class_id])
        else:
            predicted_class_id = -1  # If no prediction is made, assign an invalid class ID
            print("Unknown")
        print("")
        # Print results to console

        # Display the results (show=True should handle this if the method supports it)
    except Exception as e:
        print(f"An error occurred: {e}")


# Optionally, print additional information or save results
# print(results.xyxy)  # Print bounding boxes and class predictions
# results.save()  # Save the image with annotations
# Out:
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(8).jpg: 224x224 (no detections), 37.1ms
# Speed: 0.0ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Unknown
#
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8)_augmented_2.jpg
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(8)_augmented_2.jpg: 224x224 1 TakeAway, 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# TakeAWay
#
# Performing object detection on image: C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1)_augmented_1.jpg
#
# ...

# %% [markdown]
# classification Model class:

# %%
from PIL import Image
from ultralytics import YOLO 

class ClassificationModel:
    def __init__(self, model_path, class_labels):
        """
        Initialize the model with the given path and class labels.
        
        Args:
        model_path (str): Path to the trained model file.
        class_labels (list): A list of class labels.
        """
        self.model_path = model_path
        self.class_labels = class_labels
        try:
            self.model = YOLO(self.model_path)
        except Exception as e:
            print(f"Failed to load model from {model_path}: {e}")   


    def load_model(self):
        """
        Load the model from the given path.
        """
        self.model = YOLO(self.model_path)


    def predict(self, image_path, conf=0.5):
        """
        Predict the class of an image.
        
        Args:
        image_path (str): Path to the image file.
        conf (float): Confidence threshold for predictions.
        
        Returns:
        str: The predicted class label or 'Unknown' if prediction fails.
        """
        try:
            # Perform prediction
            results = self.model.predict(image_path, conf=conf, show=False)
            
            # Extract the predicted class with the highest confidence
            if len(results) > 0 and len(results[0].boxes) > 0:
                predicted_class_id = int(results[0].boxes[0].cls)
                return self.class_labels[predicted_class_id]
            else:
                return "Unknown"  # Return Unknown if no prediction is made
            
        except Exception as e:
            print(f"An error occurred while predicting on {image_path}: {e}")
            return "Error"

# %%
# Example usage
# model_coffee_type
model_path = r"resources\\MLmodels\\coffee_type_classification\\coffee_type_classification_v1.pt"
class_labels = ['Cappuccino', 'Espresso', 'Black Coffee']
model_coffee_type = ClassificationModel(model_path, class_labels)

image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
predicted_label = model_coffee_type.predict(image_path, conf=0.5)
print(f"Predicted coffee type: {predicted_label}")

# model_crema
class_labels = ['No_Crema', 'Crema']
model_path = r"resources\\MLmodels\\crema_classification\\crema_classification_v1.pt"
model_crema = ClassificationModel(model_path, class_labels)

image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
predicted_label = model_crema.predict(image_path, conf=0.5)
print(f"Predicted crema: {predicted_label}")

# model_served_way
class_labels = ['No_Served_Way', 'Yes_Served_Way']
model_path = r"resources\\MLmodels\\served_way_classification\\served_way_classification_v1.pt"
model_served_way = ClassificationModel(model_path, class_labels)

image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
predicted_label = model_served_way.predict(image_path, conf=0.5)
print(f"Predicted served way: {predicted_label}")

# model_type_of_cup
class_labels = ['TakeAWay', 'Cup']
model_path = r"resources\\MLmodels\\type_of_cup_classification\\type_of_cup_classification_v1.pt"
model_type_of_cup = ClassificationModel(model_path, class_labels)

image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
predicted_label = model_type_of_cup.predict(image_path, conf=0.5)
print(f"Predicted type of cup: {predicted_label}")
# Out:
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 1 Black, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Predicted coffee type: Black Coffee
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Cremas, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Predicted crema: No_Crema
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Served_Ways, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Predicted served way: No_Served_Way
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 Cups, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 7.0ms postprocess per image at shape (1, 3, 224, 224)
# ...

# %% [markdown]
# object detection Model class:

# %%
from PIL import Image
from ultralytics import YOLO 

class ObjectDetectionModel:
    def __init__(self, model_path):
        """
        Initialize the model with the given path and class labels.
        
        Args:
        model_path (str): Path to the trained model file.
        class_labels (list): A list of class labels.
        """
        self.model_path = model_path
        try:
            self.model = YOLO(self.model_path)
        except Exception as e:
            print(f"Failed to load model from {model_path}: {e}")   


    def load_model(self):
        """
        Load the model from the given path.
        """
        self.model = YOLO(self.model_path)


    def predict(self, image_path):
        """
        Predict the class of an image.
        
        Args:
        image_path (str): Path to the image file.
        conf (float): Confidence threshold for predictions.
        
        Returns:
        str: The predicted class label or 'Unknown' if prediction fails.
        """
        try:
            # Perform prediction
            results = self.model.predict(image_path)
            if len(results) > 0 and len(results[0].boxes) > 0:
                return True
            else:
                return False
            
        except Exception as e:
            print(f"An error occurred while predicting on {image_path}: {e}")
            return False

# %%
# Example usage of the ObjectDetectionModel
model_path = r"resources\\MLmodels\\object_detection\\object_detection_v1.pt"
model_object_detection = ObjectDetectionModel(model_path)

image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
predicted_label = model_object_detection.predict(image_path)
print(f"Predicted object1: {predicted_label}")

image_path = r"C:\\Users\omers\\OneDrive\\Desktop\\coffee6.png" 
predicted_label = model_object_detection.predict(image_path)
print(f"Predicted object2: {predicted_label}")

image_path = r"C:\\Users\omers\\OneDrive\\Desktop\\food1.png" 
predicted_label = model_object_detection.predict(image_path)
print(f"Predicted object3: {predicted_label}")

image_path = r"C:\\Users\omers\\OneDrive\\Desktop\\coffee7.png"
predicted_label = model_object_detection.predict(image_path)
print(f"Predicted object4: {predicted_label}")

image_path = r"C:\\Users\omers\\OneDrive\\Desktop\\coffe1111.png"
predicted_label = model_object_detection.predict(image_path)
print(f"Predicted object5: {predicted_label}")
# Out:
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 640x640 2 Coffee_cups, 140.0ms
# Speed: 0.0ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Predicted object1: True
#
# image 1/1 C:\Users\omers\OneDrive\Desktop\coffee6.png: 480x640 2 Coffee_cups, 103.3ms
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Predicted object2: True
#
# image 1/1 C:\Users\omers\OneDrive\Desktop\food1.png: 416x640 (no detections), 95.1ms
# Speed: 0.0ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Predicted object3: False
#
# image 1/1 C:\Users\omers\OneDrive\Desktop\coffee7.png: 640x480 3 Coffee_cups, 99.4ms
# Speed: 11.9ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Predicted object4: True
#
# image 1/1 C:\Users\omers\OneDrive\Desktop\coffe1111.png: 448x640 2 Coffee_cups, 89.8ms
# ...

# %% [markdown]
# wrapper class for object detaction and for all clasification models:

# %%
from PIL import Image
from ultralytics import YOLO 
import json


class ModelsWrapper:
    def __init__(self, json_file_path):
        self.classifications = {}
        self.object_detection = None
        self.load_models(json_file_path)

    def load_models(self, json_file_path):
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        
        # Load classification models
        for classification in data["clasifications"]:
            model_path = classification["model_path"]
            class_labels = classification["class_labels"]
            classification_name = classification["classification_name"]
            self.classifications[classification_name] = ClassificationModel(model_path, class_labels)

        # Load object detection model
        if "coffee_detection" in data:
            detection_model_path = data["coffee_detection"]["model_path"]
            self.object_detection = ObjectDetectionModel(detection_model_path)
        else:
            print("omer  No object detection model found in the JSON file")

    def predict_without_detect(self, image_path, classifications):
        """
        Perform predictions for specified classifications without object detection, using specific confidence thresholds.

        Args:
        image_path (str): Path to the image file.
        classifications (dict): Dictionary with classification names as keys and confidence thresholds as values.
                                esamplle: {"coffe_type": 0.5, "crema": 0.5, "served_way": 0.5, "type_of_cup": 0.5}
        Returns:
        dict: Dictionary with classification names as keys and predictions as values or error messages.
        """
        predictions = {}
        for classification_name, confidence in classifications.items():
            if classification_name in self.classifications:
                model = self.classifications[classification_name]
                try:
                    # Use the specific confidence threshold for this prediction
                    prediction = model.predict(image_path, conf=confidence)
                except Exception as e:
                    prediction = f"An error occurred: {e}"
                predictions[classification_name] = prediction
            else:
                predictions[classification_name] = "Classification not found"
        return predictions
    
    def predict_with_detect(self, image_path, classifications):
        """
        Perform predictions for specified classifications with object detection.

        Args:
        image_path (str): Path to the image file.
        classifications (dict): Dictionary with classification names as keys and confidence thresholds as values.
                                esamplle: {"coffe_type": 0.5, "crema": 0.5, "served_way": 0.5, "type_of_cup": 0.5}

        Returns:
        dict: Dictionary with classification names as keys and predictions as values.
        """
        predictions = {}
        if self.object_detection is not None:
            try:
                object_detected = self.detection(image_path)
            except Exception as e:
                object_detected = False
                print(f"An error occurred: {e}")
            # If object is detected, perform predictions
            if object_detected:
                return self.predict_without_detect(image_path, classifications)
            else:
                return {"Object not detected": "No predictions"}


    def detection(self, image_path):
        """
        Perform object detection on the image.

        Args:
        image_path (str): Path to the image file.

        Returns:
        bool: True if an object is detected, False otherwise.
        """
        if self.object_detection is not None:
            try:
                object_detected = self.object_detection.predict(image_path)
            except Exception as e:
                object_detected = False
                print(f"An error occurred: {e}")
            return object_detected
        else:
            return False
    

# Example usage:
json_file_path = "resources\MLmodels\classifications_conf.json"
models_wrapper = ModelsWrapper(json_file_path)
image_path = r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(1).jpg"
classifications_to_predict = {
    "coffe_type": 0.5,
    "crema": 0.5,
    "served_way": 0.5,
    "type_of_cup": 0.5,
}
predictions = models_wrapper.predict_without_detect(image_path, classifications_to_predict)
predictions_with_detect = models_wrapper.predict_with_detect(image_path, classifications_to_predict)
print("predicted_labels:")
print(predictions)
print("predicted_labels_with_detect:")
print(predictions_with_detect)


image_paths = [
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(8).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(10).jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(4)_augmented_1.jpg",
                r"C:\\git\\coffee_ml\\coffeeML\\Coffee_photos\\augmented_images_folder\\coffe_image(28)_augmented_11.jpg",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffe1111.png",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffee6.png",
                r"C:\\Users\\omers\\OneDrive\\Desktop\\coffee7.png",
                r"C:\\Users\omers\\OneDrive\\Desktop\\food1.png" 
               ]

results = {}
for image_path in image_paths:
    print(f"Performing predictions on image: {image_path}")
    predictions = models_wrapper.predict_with_detect(image_path, classifications_to_predict)
    results[image_path] = predictions

print("Results:")
for image_path, predictions in results.items():
    print("="*50)
    print(f"Image: {image_path}")
    print(predictions)
    print("="*50)
    print("")
# Out:
# <>:103: SyntaxWarning: invalid escape sequence '\M'
# <>:103: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\omers\AppData\Local\Temp\ipykernel_9736\2333289605.py:103: SyntaxWarning: invalid escape sequence '\M'
#   json_file_path = "resources\MLmodels\classifications_conf.json"
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 1 Black, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Cremas, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 C:\git\coffee_ml\coffeeML\Coffee_photos\augmented_images_folder\coffe_image(1).jpg: 224x224 2 No_Served_Ways, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
